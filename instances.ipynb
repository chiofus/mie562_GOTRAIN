# %% [markdown]
# Please use the 'get_instances' function below to get the 10 instances to compare the models with.

# %%
# %run ./scenario.ipynb

# %%
from typing import List, Dict

# %%
#Seeds to use

seeds: List[str|int] = [
    "GOTRAIN",
    "SCHEDULE",
    "12345",
    9999999999999,
    "SCENARIO123",
    "SCENARIO321",
    21731273,
    5125912390123,
    1239129521,
    1231
]

# %%
def get_instances() -> List[Dict[str, Dict[str, int]]]:
    scenarios = []

    for seed in seeds:
        scenarios.append(generate_scenario(seed))

    return scenarios

# %%
get_instances()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_instances()
#
# Cell In[4], line 5, in get_instances()
#       2 scenarios = []
#       4 for seed in seeds:
# ----> 5     scenarios.append(generate_scenario(seed))
#       7 return scenarios
#
# File /tmp/ipykernel_22205/1629624951.py:14, in generate_scenario(seed)
#      10 if seed is None: seed = time_ns()%(2**32-1)
#      12 if type(seed) is not int: seed = sum([ord(char) for char in seed])
# ---> 14 np.random.seed(seed)
#      16 scenario: Dict[str, Dict[str, int]] = {}
#      18 #Initializing dicts
#
# File numpy/random/mtrand.pyx:4828, in numpy.random.mtrand.seed()
#
# File numpy/random/mtrand.pyx:254, in numpy.random.mtrand.RandomState.seed()
#
# File numpy/random/_mt19937.pyx:168, in numpy.random._mt19937.MT19937._legacy_seeding()
#
# File numpy/random/_mt19937.pyx:182, in numpy.random._mt19937.MT19937._legacy_seeding()
#
# ValueError: Seed must be between 0 and 2**32 - 1
